# %%
import pandas

# %%
platy = pandas.read_csv("platy_2021_02.csv", index_col='cislo_zamestnance')
platy.head()
# Out:
#                       plat
# cislo_zamestnance
# 3                  54900.0
# 6                  54800.0
# 7                  36400.0
# 8                  47900.0
# 16                 34200.0

# %%
platy.plot()
# Out:
# <Axes: xlabel='cislo_zamestnance'>

# %%
platy.plot(kind="hist", color="green", bins=5, grid=True)
# Out:
# <Axes: ylabel='Frequency'>
